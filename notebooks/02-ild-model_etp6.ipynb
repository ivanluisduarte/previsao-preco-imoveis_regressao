# %% [markdown]
# # Nota Importante
# O propósito deste notebook é encontrar o melhor modelo para os dados Sem Outliers. Já trabalhamos com praticamente tudo que era possível com LinearRegression. Vamos agora utilizar Ridge como regressor e tentar encontrar uma solução melhor que aquelas que já encontramos nas etapas anteriores.
#
# Vamos combinar opções de hiperparâmetros para regularizar os coeficientes das diversas features polinomais criadas nas etapas anteriores e encontrar um novo modelo melhor que o que temos até o momento.
#
# ---
#
# Leia o arquivo [README.md](../README.md) para detalhes sobre a base o projeto.
#
# Leia o arquivo de [01_dicionario_de_dados.md](../referencias/01_dicionario_de_dados.md) para detalhes sobre a base.
#
# Ao importar esse arquivo [src.graficos](./src/graficos.py), em tema seaborn é aplicado.

# %% [markdown]
# # Imports e configurações

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
import seaborn as sns
import warnings


from sklearn.compose import ColumnTransformer # constrói um pipeline para diferentes colunas
from sklearn.linear_model import (
    # ElasticNet, # uma combinação de Lasso e Ridge para regularização de features
    # Lasso, # regularização é dada pela norma l1
    LinearRegression, # modelo de regressão linear com coeficientes estimados usando o método dos mínimos quadrados
    Ridge, # regularização é dada pela norma l2
)
from sklearn.pipeline import Pipeline # enfileira diferentes procedimentos
from sklearn.preprocessing import (  # Módulo de pré-processamento de dados
    OneHotEncoder,       # Codifica variáveis categóricas nominais, transformando-as em uma matriz binária (uma coluna para cada categoria)
    OrdinalEncoder,      # Codifica variáveis categóricas ordinais, convertendo categorias em inteiros com base na ordem
    PolynomialFeatures,  # Cria features polinomiais e de multiplicação entre elas.
    PowerTransformer,    # Aplica uma transformação de potência para estabilizar a variância e tornar os dados mais gaussianos
    QuantileTransformer, # Realiza uma transformação baseada em quantis, escalando os dados para uma distribuição uniforme ou normal
    # RobustScaler,        # Normaliza os dados utilizando estatísticas robustas (mediana e intervalo interquartil), útil para dados com outliers
    StandardScaler,      # Normaliza os dados para que tenham média zero e desvio padrão um, útil para dados normalmente distribuídos
)

from src.auxiliares import (
    fnc_dataframe_coeficientes, # função que combina os coeficientes de um gridsearch com os nomes das features em um DataFrame
    fnc_describe_numericas_personalizado, # função que retorna um dataframe com o describe() de variáveis numéricas enriquecido com colunas de tipo, ausência, variabilidade, outliers e normalidade
    fnc_exibir_dataframe_resultados, # função que exibe um DataFrame estilizado no notebook ou um DataFrame simples no console
)
from src.config import (
    DADOS_X_TEST,
    DADOS_X_TRAIN,
    DADOS_X_VALIDATION,
    DADOS_Y_TEST,
    DADOS_Y_TRAIN,
    DADOS_Y_VALIDATION,
)
from src.graficos import (
    PALETTE_TEMPERATURA,
    plot_coeficientes, # função para plotar um gráfico de barras horizontais dos coeficientes de um modelo
    plot_comparar_metricas_modelos, # função para plotar boxplots de diferentes modelos para diferentes méticas de um dataframe de resultado
    plot_residuos_estimador, # função que plota 3 gráficos de resíduos para um estimador, um histograma e dois de dispersão
)
from src.models import (
    fnc_grid_search_cv_regressor, # função para planejar modelos de regressão validação cruzada e grid search
    fnc_treinar_e_validar_modelos_regressao, # função para treinar modelos de regressão com validação cruzada usando um dicionário de regressores
)

# %%
pd.options.display.max_rows = 15
pd.options.display.max_columns = None
pd.options.display.float_format = '{:.2f}'.format

# Ignorar UserWarnings
warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# # Modelagem para melhoria do modelo da etapa 4

# %% [markdown]
# ## Carregando os arquivos de treino/teste e validação criados na etapa 2
#
# Origem: [01-ild-eda.ipynb](01-ild-eda.ipynb)
#
# - `median_income`: renda mediana no grupo de blocos (em dezenas de milhares de dólares)
# - `housing_median_age`: idade mediana das casas no grupo de blocos
# - `total_rooms`: número cômodos no grupo de blocos
# - `total_bedrooms`: número de quartos no grupo de blocos
# - `population`: população do grupo de blocos
# - `households`: domicílios no grupo de blocos
# - `latitude`: latitude do grupo de blocos
# - `longitude`: longitude do grupo de blocos
# - `ocean_proximity`: proximidade do oceano
#   - `NEAR BAY`: perto da baía
#   - `<1H OCEAN`: a menos de uma hora do oceano
#   - `INLAND`: no interior
#   - `NEAR OCEAN`: perto do oceano
# - `median_house_value`: valor mediano das casas no grupo de blocos (em dólares)
# - `median_income_cat`: categorias baseadas no valor da mediana do salário anual -> `median_income`
# - `housing_median_age_cat`: categorias baseadas no valor da mediana das idades das casas -> `housing_median_age`
# - `population_cat`: categorias baseadas no tamanho da população -> `population`
# - `rooms_per_household`: `total_rooms` / `households`
# - `population_per_household`: `population` / `households`
# - `bedrooms_per_room`: `total_bedrooms` / `total_rooms`

# %%
# dados já separados como X e y de treino, teste e validação
X_train = pd.read_parquet(DADOS_X_TRAIN)
y_train = pd.read_parquet(DADOS_Y_TRAIN)

print('X_train.shape', X_train.shape)
print('y_train.shape', y_train.shape)
# Out:
# X_train.shape (12862, 15)
# y_train.shape (12862, 1)

# %%
display(
    X_train.head(1),
    y_train.head(1),
)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4816    -118.28     33.91                  41          620             133
#
#       population  households  median_income ocean_proximity median_income_cat  \
# 4816         642         162           2.65       <1H OCEAN      1.5 <= x < 3
#
#      housing_median_age_cat   population_cat  rooms_per_household  \
# 4816                40 <= x  500 <= x < 1000                 3.83
#
#       population_per_household  bedrooms_per_room
# 4816                      3.96               0.21
#       median_house_value
# 4816              159600

# %% [markdown]
# ## Definindo as estratégias para os modelos
# Vamos manter a estratégia ganhadora do GRID SEARCH da etapa anterior e vamos experimentar regularizar os coeficiente das diversas features.

# %%
coluna_target = ['median_house_value']

# define as colunas a serem transformadas 
colunas_one_hot_encoder = ['ocean_proximity',]
colunas_ordinal_encoder = ['median_income_cat', 'housing_median_age_cat', 'population_cat',]
colunas_standard_scaler_poly = ['longitude', 'latitude', 'housing_median_age']
colunas_power_tranformer_poly = X_train.columns.difference( # colunas restantes com outliers
    colunas_one_hot_encoder + colunas_ordinal_encoder + colunas_standard_scaler_poly
).to_list()


preprocessamento_categoricas = ColumnTransformer(
    transformers=[
        ('one_hot_encoder', OneHotEncoder(drop='first'), colunas_one_hot_encoder), # drop='first' para evitar a dummy variable trap
        ('ordinal_encoder', OrdinalEncoder(categories='auto'), colunas_ordinal_encoder), # categories='auto' para usar as categorias do dataframe
    ],
    remainder='passthrough', # mantém as colunas que não foram transformadas
)


# enfileira uma transformação depois de outra
pipeline_standard_poly = Pipeline(
    steps=(
        ('standard_scaler', StandardScaler()),
        ('poly', PolynomialFeatures(degree=3, interaction_only=False, include_bias=False)),
    ),
)

# enfileira uma transformação depois de outra
pipeline_power_poly = Pipeline(
    steps=(
        ('power_transformer', PowerTransformer(method='box-cox')), # box-cox só funciona para números positivos
        ('poly', PolynomialFeatures(degree=3, interaction_only=True, include_bias=False)),
    ),
)

# define o preprocessamento das colunas - o preprocessamento é feito em ordem
preprocessamento_polinomiais = ColumnTransformer(
    transformers=preprocessamento_categoricas.transformers + [
        ('standard_scaler_poly', pipeline_standard_poly, colunas_standard_scaler_poly),
        ('power_transformer_poly', pipeline_power_poly, colunas_power_tranformer_poly),
    ],
)



target_transfomer = QuantileTransformer(output_distribution='normal')



# algorítmos de avaliação de modelos de regressão a utilizar nessa análise - https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
dct_metricas_modelos = {
        # 'd2_absolute_error_score'            : 'd2ae',  # melhor = 1.0 -> metrics.d2_absolute_error_score
        # 'explained_variance'                 : 'evs',   # melhor = 1.0 -> metrics.explained_variance_score
        # 'neg_max_error'                      : 'maxe',  # melhor = 0.0 -> metrics.max_error
        'neg_mean_absolute_error'            : 'mae',   # melhor = 0.0 -> metrics.mean_absolute_error
        # 'neg_mean_absolute_percentage_error' : 'mape',  # melhor = 0.0 -> metrics.mean_absolute_percentage_error
        # 'neg_mean_gamma_deviance'            : 'mgd',   # melhor = 0.0 -> metrics.mean_gamma_deviance
        # 'neg_mean_poisson_deviance'          : 'mpd',   # melhor = 0.0 -> metrics.mean_poisson_deviance
        # 'neg_mean_squared_error'             : 'mse',   # melhor = 0.0 -> metrics.mean_squared_error
        # 'neg_mean_squared_log_error'         : 'msle',  # melhor = 0.0 -> metrics.mean_squared_log_error
        # 'neg_median_absolute_error'          : 'medae', # melhor = 0.0 -> metrics.median_absolute_error
        'neg_root_mean_squared_error'        : 'rmse',  # melhor = 0.0 -> metrics.root_mean_squared_error
        # 'neg_root_mean_squared_log_error'    : 'rmsle', # melhor = 0.0 -> metrics.root_mean_squared_log_error
        'r2'                                 : 'r2',    # melhor = 1.0 -> metrics.r2_score
}


refit = 'neg_root_mean_squared_error' # algorítmos de avaliação de modelos de regressão que será usado como avaliador do melhor modelo

# %% [markdown]
# ## Estratégia de Grid Search para a regularização com `Ridge`
# Vamos experimentar diferentes valores, para [alpha].
#
# Alpha igual a 0.0 seria o mesmo que a `LinearRegression` das epatas anteriores, mas o padrão é 1.0, que também vamos experimentar.

# %%
# essa nova estratégia será somada à estratégia já conhecida na parte de target.
# lembrando que muitos cenários e muitos registros podem levar à lentidão no processamento.
param_grid = {
    'regressor__regressor__alpha': (0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0), # 1.0 é o padrão
}

pprint(param_grid)


## Construindo o plano de execução com as novas estratégias/cenários
grid_search = fnc_grid_search_cv_regressor(
    preprocessor=preprocessamento_polinomiais, # obrigatório se no grid search tentar variar o preprocessamento
    regressor=Ridge(),
    target_transformer=target_transfomer,
    param_grid=param_grid,
    scoring=tuple(dct_metricas_modelos.keys()),
    refit = refit,
)

display(grid_search)
# Out:
# {'regressor__regressor__alpha': (0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0)}
# GridSearchCV(cv=KFold(n_splits=5, random_state=255, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat',
#                                                                                                                'housing_median_age_cat',
#                                                                                                                'population_cat']),
#                                                                                                              ('stan...
#                                                                                                                'rooms_per_household',
#                                                                                                                'total_bedrooms',
#                                                                                                                'total_rooms'])])),
#                                                                             ('regressor',
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-2,
#              param_grid={'regressor__regressor__alpha': (0.001, 0.005, 0.01,
#                                                          0.05, 0.1, 0.5, 1.0)},
#              refit='neg_root_mean_squared_error',
#              scoring=('neg_mean_absolute_error', 'neg_root_mean_squared_error',
#                       'r2'),
#              verbose=1)

# %% [markdown]
# ## Treinando e avaliando os modelos de acordo com o plano construído acima
# Nesse etapa conseguimos saber quais são os melhores hiperparametros que entregaram o melhor modelo

# %%
grid_search.fit(X=X_train, y=y_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=255, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat',
#                                                                                                                'housing_median_age_cat',
#                                                                                                                'population_cat']),
#                                                                                                              ('stan...
#                                                                                                                'rooms_per_household',
#                                                                                                                'total_bedrooms',
#                                                                                                                'total_rooms'])])),
#                                                                             ('regressor',
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-2,
#              param_grid={'regressor__regressor__alpha': (0.001, 0.005, 0.01,
#                                                          0.05, 0.1, 0.5, 1.0)},
#              refit='neg_root_mean_squared_error',
#              scoring=('neg_mean_absolute_error', 'neg_root_mean_squared_error',
#                       'r2'),
#              verbose=1)

# %%
# informa os melhores parametros encontrados pelo GRID SEARCH
# no nosso caso, só planejamos a busca na transformação de target
grid_search.best_params_
# Out:
# {'regressor__regressor__alpha': 0.05}

# %%
# se refere à metrica escolhida para comparação na variável 'refit' da estratégia do GRID SEARCH
grid_search.best_score_
# Out:
# -52083.2691691591

# %% [markdown]
# ### Sobre o melhor modelo
# - Vemos que foram 35 jobs/fits/processamentos, pois foram 7 alternativas de regularização e 5 validações cruzadas [o default da função em `n_splits`];
# - A melhor alternativa de regularização foi [alpha=0.05];
# - Pelo score, percebemos novamente que atingimos um novo melhor modelo, mas com mais complexidade. Lembrando que considerando o `RMSE` como validador;

# %% [markdown]
# ## Avaliando o modelo criado

# %%
# se esse numero for muito grande, melhor apresentar num dataframe vertical
# por causa das configurações de pandas feitas no inicio
len(grid_search.best_estimator_.regressor_['regressor'].coef_)
# Out:
# 117

# %% [markdown]
# 117 é variável demais para visualizar, vamos ver apenas as primeiras mais relevantes para o modelo.

# %%
df_coeficientes = fnc_dataframe_coeficientes(
    colunas      = grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out(),
    coeficientes = grid_search.best_estimator_.regressor_['regressor'].coef_,
    flg_mostrar_dataframe=False,
    flg_horizontal=False,
)
df_coeficientes.head()
# Out:
#                                                     coeficiente
# power_transformer_poly__population                         5.09
# power_transformer_poly__households median_income           3.54
# power_transformer_poly__population rooms_per_ho...         2.52
# power_transformer_poly__households rooms_per_ho...        -2.43
# power_transformer_poly__population rooms_per_ho...        -2.41

# %%
df_coeficientes.tail().style.format(precision=10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_561c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_561c5_level0_col0" class="col_heading level0 col0" >coeficiente</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_561c5_level0_row0" class="row_heading level0 row0" >power_transformer_poly__median_income rooms_per_household total_bedrooms</th>
#       <td id="T_561c5_row0_col0" class="data row0 col0" >-0.0062410272</td>
#     </tr>
#     <tr>
#       <th id="T_561c5_level0_row1" class="row_heading level0 row1" >power_transformer_poly__bedrooms_per_room median_income rooms_per_household</th>
#       <td id="T_561c5_row1_col0" class="data row1 col0" >0.0036003481</td>
#     </tr>
#     <tr>
#       <th id="T_561c5_level0_row2" class="row_heading level0 row2" >ordinal_encoder__population_cat</th>
#       <td id="T_561c5_row2_col0" class="data row2 col0" >-0.0019861672</td>
#     </tr>
#     <tr>
#       <th id="T_561c5_level0_row3" class="row_heading level0 row3" >power_transformer_poly__bedrooms_per_room households median_income</th>
#       <td id="T_561c5_row3_col0" class="data row3 col0" >0.0016914946</td>
#     </tr>
#     <tr>
#       <th id="T_561c5_level0_row4" class="row_heading level0 row4" >standard_scaler_poly__housing_median_age^3</th>
#       <td id="T_561c5_row4_col0" class="data row4 col0" >0.0010663647</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_coeficientes[df_coeficientes['coeficiente'] == 0.0].size
# Out:
# 0

# %%
plot_coeficientes(df_coeficientes, precisao=2,)

# %% [markdown]
# Compararando com a etapa anterior, podemos ver que a transformação das variáveis foi capaz de trocar bastante a relevância das variáveis para o modelo, trocando bastante sua ordem.

# %% [markdown]
# ## Vamos comparar nosso novo modelo com os que tinhamos antes

# %%
# regressores atualizado com a melhor estratégia encontrada pelo GRID SEARCH
# apenas para comparar com o melhor modelo que sairá do grid search
regressors = {
    # Modelo incial simples apenas para comparação
    'LinearRegression_simples': {
        'preprocessor': preprocessamento_categoricas,
        'regressor': LinearRegression(),
        'target_transformer': None,
    },

    # melhor até o momento,
    'LinearRegression_melhor_atual': {
        'preprocessor': preprocessamento_polinomiais,
        'regressor': LinearRegression(),
        'target_transformer': target_transfomer
    },

    # novo modelo indicado como melhor após o GRID SEARCH
    'LinearRegression_best_estimator': {
        'preprocessor':       grid_search.best_estimator_.regressor_['preprocessor'],
        'regressor':          grid_search.best_estimator_.regressor_['regressor'],
        'target_transformer': grid_search.best_estimator_.transformer_,
    }
}

pprint(regressors)
# Out:
# {'LinearRegression_best_estimator': {'preprocessor': ColumnTransformer(transformers=[('one_hot_encoder', OneHotEncoder(drop='first'),
#                                  ['ocean_proximity']),
#                                 ('ordinal_encoder', OrdinalEncoder(),
#                                  ['median_income_cat', 'housing_median_age_cat',
#                                   'population_cat']),
#                                 ('standard_scaler_poly',
#                                  Pipeline(steps=(('standard_scaler',
#                                                   StandardScaler()),
#                                                  ('poly',
#                                                   PolynomialFeatures(degree=3,
#                                                                      include_bias=False)))),
#                                  ['longitude',...,
#                                   'housing_median_age']),
#                                 ('power_transformer_poly',
#                                  Pipeline(steps=(('power_transformer',
#                                                   PowerTransformer(method='box-cox')),
#                                                  ('poly',
#                                                   PolynomialFeatures(degree=3,
#                                                                      include_bias=False,
#                                                                      interaction_only=True)))),
#                                  ['bedrooms_per_room', 'households',
#                                   'median_income', 'population',
#                                   'population_per_household',
#                                   'rooms_per_household', 'total_bedrooms',
#                                   'total_rooms'])]),
#                                      'regressor': Ridge(alpha=0.05),
#                                      'target_transformer': QuantileTransformer(output_distribution='normal')},
#  'LinearRegression_melhor_atual': {'preprocessor': ColumnTransformer(transformers=[('one_hot_encoder', OneHotEncoder(drop='first'),
#                                  ['ocean_proximity']),
#                                 ('ordinal_encoder', OrdinalEncoder(),
#                                  ['median_income_cat', 'housing_median_age_cat',
#                                   'population_cat']),
#                                 ('standard_scaler_poly',
#                                  Pipeline(steps=(('standard_scaler',
#                                                   StandardScaler()),
#                                                  ('poly',
#                                                   PolynomialFeatures(degree=3,
#                                                                      include_bias=False)))),
#                                  ['longitude',...,
#                                   'housing_median_age']),
#                                 ('power_transformer_poly',
#                                  Pipeline(steps=(('power_transformer',
#                                                   PowerTransformer(method='box-cox')),
#                                                  ('poly',
#                                                   PolynomialFeatures(degree=3,
#                                                                      include_bias=False,
#                                                                      interaction_only=True)))),
#                                  ['bedrooms_per_room', 'households',
#                                   'median_income', 'population',
#                                   'population_per_household',
#                                   'rooms_per_household', 'total_bedrooms',
#                                   'total_rooms'])]),
#                                    'regressor': LinearRegression(),
#                                    'target_transformer': QuantileTransformer(output_distribution='normal')},
#  'LinearRegression_simples': {'preprocessor': ColumnTransformer(remainder='passthrough',
#                   transformers=[('one_hot_encoder', OneHotEncoder(drop='first'),
#                                  ['ocean_proximity']),
#                                 ('ordinal_encoder', OrdinalEncoder(),
#                                  ['median_income_cat', 'housing_median_age_cat',
#                                   'population_cat'])]),
#                               'regressor': LinearRegression(),
#                               'target_transformer': None}}

# %%
df_resultados = fnc_treinar_e_validar_modelos_regressao(
    X=X_train,
    y=y_train,
    regressors=regressors,
    scoring=tuple(dct_metricas_modelos.keys()),
)

fnc_exibir_dataframe_resultados(df_resultados)
# Out:
# Index(['model', 'fit_time', 'score_time', 'test_neg_mean_absolute_error',
#        'test_neg_root_mean_squared_error', 'test_r2', 'time_seconds'],
#       dtype='object')
# <style type="text/css">
# #T_17711_row0_col1, #T_17711_row2_col6, #T_17711_row4_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_17711_row0_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_17711_row0_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_17711_row0_col4 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_17711_row0_col5 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_17711_row0_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_17711_row1_col1, #T_17711_row1_col2, #T_17711_row1_col3, #T_17711_row1_col4, #T_17711_row1_col5, #T_17711_row1_col6, #T_17711_row2_col1, #T_17711_row3_col1, #T_17711_row3_col6, #T_17711_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_17711_row2_col2, #T_17711_row2_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_17711_row2_col4, #T_17711_row3_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_17711_row2_col5, #T_17711_row4_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_17711_row3_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_17711_row3_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_17711_row3_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_17711_row4_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_17711_row4_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_17711_row4_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_17711_row5_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_17711_row5_col2 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_17711_row5_col3, #T_17711_row12_col6 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_17711_row5_col4, #T_17711_row5_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_17711_row5_col6, #T_17711_row8_col1, #T_17711_row8_col6, #T_17711_row12_col4 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_17711_row6_col1 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_17711_row6_col2, #T_17711_row7_col1, #T_17711_row7_col6, #T_17711_row10_col3, #T_17711_row10_col4, #T_17711_row10_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_17711_row6_col3 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_17711_row6_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_17711_row6_col5, #T_17711_row8_col5 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_17711_row6_col6 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_17711_row7_col2, #T_17711_row11_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_17711_row7_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_17711_row7_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_17711_row7_col5 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_17711_row8_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_17711_row8_col3, #T_17711_row13_col4 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_17711_row8_col4, #T_17711_row14_col3 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_17711_row9_col1, #T_17711_row9_col6 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_17711_row9_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_17711_row9_col3 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_17711_row9_col4, #T_17711_row14_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_17711_row9_col5, #T_17711_row14_col5 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_17711_row10_col1, #T_17711_row10_col6 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_17711_row10_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_17711_row11_col1, #T_17711_row11_col6 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_17711_row11_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_17711_row11_col4 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_17711_row11_col5 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_17711_row12_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_17711_row12_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_17711_row12_col3 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_17711_row12_col5 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_17711_row13_col1, #T_17711_row13_col6 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_17711_row13_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_17711_row13_col3 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_17711_row13_col5 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_17711_row14_col1, #T_17711_row14_col6 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_17711_row14_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# </style>
# <table id="T_17711">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17711_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_17711_level0_col1" class="col_heading level0 col1" >fit_time</th>
#       <th id="T_17711_level0_col2" class="col_heading level0 col2" >score_time</th>
#       <th id="T_17711_level0_col3" class="col_heading level0 col3" >test_neg_mean_absolute_error</th>
#       <th id="T_17711_level0_col4" class="col_heading level0 col4" >test_neg_root_mean_squared_error</th>
#       <th id="T_17711_level0_col5" class="col_heading level0 col5" >test_r2</th>
#       <th id="T_17711_level0_col6" class="col_heading level0 col6" >time_seconds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17711_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17711_row0_col0" class="data row0 col0" >LinearRegression_simples</td>
#       <td id="T_17711_row0_col1" class="data row0 col1" >0.037603</td>
#       <td id="T_17711_row0_col2" class="data row0 col2" >0.018299</td>
#       <td id="T_17711_row0_col3" class="data row0 col3" >-40752.245328</td>
#       <td id="T_17711_row0_col4" class="data row0 col4" >-55293.325335</td>
#       <td id="T_17711_row0_col5" class="data row0 col5" >0.649683</td>
#       <td id="T_17711_row0_col6" class="data row0 col6" >0.055902</td>
#     </tr>
#     <tr>
#       <th id="T_17711_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_17711_row1_col0" class="data row1 col0" >LinearRegression_simples</td>
#       <td id="T_17711_row1_col1" class="data row1 col1" >0.028190</td>
#       <td id="T_17711_row1_col2" class="data row1 col2" >0.013048</td>
#       <td id="T_17711_row1_col3" class="data row1 col3" >-43153.132860</td>
#       <td id="T_17711_row1_col4" class="data row1 col4" >-65273.979368</td>
#       <td id="T_17711_row1_col5" class="data row1 col5" >0.537121</td>
#       <td id="T_17711_row1_col6" class="data row1 col6" >0.041238</td>
#     </tr>
#     <tr>
#       <th id="T_17711_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_17711_row2_col0" class="data row2 col0" >LinearRegression_simples</td>
#       <td id="T_17711_row2_col1" class="data row2 col1" >0.031044</td>
#       <td id="T_17711_row2_col2" class="data row2 col2" >0.015590</td>
#       <td id="T_17711_row2_col3" class="data row2 col3" >-42344.177226</td>
#       <td id="T_17711_row2_col4" class="data row2 col4" >-58983.680481</td>
#       <td id="T_17711_row2_col5" class="data row2 col5" >0.625750</td>
#       <td id="T_17711_row2_col6" class="data row2 col6" >0.046634</td>
#     </tr>
#     <tr>
#       <th id="T_17711_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_17711_row3_col0" class="data row3 col0" >LinearRegression_simples</td>
#       <td id="T_17711_row3_col1" class="data row3 col1" >0.028815</td>
#       <td id="T_17711_row3_col2" class="data row3 col2" >0.014360</td>
#       <td id="T_17711_row3_col3" class="data row3 col3" >-42839.980813</td>
#       <td id="T_17711_row3_col4" class="data row3 col4" >-58944.889944</td>
#       <td id="T_17711_row3_col5" class="data row3 col5" >0.635304</td>
#       <td id="T_17711_row3_col6" class="data row3 col6" >0.043175</td>
#     </tr>
#     <tr>
#       <th id="T_17711_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_17711_row4_col0" class="data row4 col0" >LinearRegression_simples</td>
#       <td id=

# %%
fnc_exibir_dataframe_resultados(df_resultados.groupby('model').mean())
# Out:
# <style type="text/css">
# #T_16fd1_row0_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_16fd1_row0_col1 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_16fd1_row0_col2, #T_16fd1_row0_col3, #T_16fd1_row0_col4, #T_16fd1_row1_col0, #T_16fd1_row1_col1, #T_16fd1_row1_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_16fd1_row0_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_16fd1_row1_col2 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_16fd1_row1_col3 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_16fd1_row1_col4 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_16fd1_row2_col0, #T_16fd1_row2_col1, #T_16fd1_row2_col2, #T_16fd1_row2_col3, #T_16fd1_row2_col4, #T_16fd1_row2_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_16fd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16fd1_level0_col0" class="col_heading level0 col0" >fit_time</th>
#       <th id="T_16fd1_level0_col1" class="col_heading level0 col1" >score_time</th>
#       <th id="T_16fd1_level0_col2" class="col_heading level0 col2" >test_neg_mean_absolute_error</th>
#       <th id="T_16fd1_level0_col3" class="col_heading level0 col3" >test_neg_root_mean_squared_error</th>
#       <th id="T_16fd1_level0_col4" class="col_heading level0 col4" >test_r2</th>
#       <th id="T_16fd1_level0_col5" class="col_heading level0 col5" >time_seconds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16fd1_level0_row0" class="row_heading level0 row0" >LinearRegression_best_estimator</th>
#       <td id="T_16fd1_row0_col0" class="data row0 col0" >1.088691</td>
#       <td id="T_16fd1_row0_col1" class="data row0 col1" >0.023987</td>
#       <td id="T_16fd1_row0_col2" class="data row0 col2" >-36555.131893</td>
#       <td id="T_16fd1_row0_col3" class="data row0 col3" >-52083.167211</td>
#       <td id="T_16fd1_row0_col4" class="data row0 col4" >0.703397</td>
#       <td id="T_16fd1_row0_col5" class="data row0 col5" >1.112678</td>
#     </tr>
#     <tr>
#       <th id="T_16fd1_level0_row1" class="row_heading level0 row1" >LinearRegression_melhor_atual</th>
#       <td id="T_16fd1_row1_col0" class="data row1 col0" >1.129826</td>
#       <td id="T_16fd1_row1_col1" class="data row1 col1" >0.026981</td>
#       <td id="T_16fd1_row1_col2" class="data row1 col2" >-36754.069945</td>
#       <td id="T_16fd1_row1_col3" class="data row1 col3" >-52438.774353</td>
#       <td id="T_16fd1_row1_col4" class="data row1 col4" >0.699368</td>
#       <td id="T_16fd1_row1_col5" class="data row1 col5" >1.156807</td>
#     </tr>
#     <tr>
#       <th id="T_16fd1_level0_row2" class="row_heading level0 row2" >LinearRegression_simples</th>
#       <td id="T_16fd1_row2_col0" class="data row2 col0" >0.031029</td>
#       <td id="T_16fd1_row2_col1" class="data row2 col1" >0.016095</td>
#       <td id="T_16fd1_row2_col2" class="data row2 col2" >-42292.683389</td>
#       <td id="T_16fd1_row2_col3" class="data row2 col3" >-59309.844310</td>
#       <td id="T_16fd1_row2_col4" class="data row2 col4" >0.614667</td>
#       <td id="T_16fd1_row2_col5" class="data row2 col5" >0.047124</td>
#     </tr>
#   </tbody>
# </table>

# %%
fnc_exibir_dataframe_resultados(df_resultados.groupby('model').median())
# Out:
# <style type="text/css">
# #T_c6cee_row0_col0, #T_c6cee_row0_col2, #T_c6cee_row0_col3, #T_c6cee_row0_col4, #T_c6cee_row0_col5, #T_c6cee_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c6cee_row0_col1, #T_c6cee_row1_col2 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_c6cee_row1_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_c6cee_row1_col3, #T_c6cee_row1_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_c6cee_row1_col5 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_c6cee_row2_col0, #T_c6cee_row2_col1, #T_c6cee_row2_col2, #T_c6cee_row2_col3, #T_c6cee_row2_col4, #T_c6cee_row2_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6cee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6cee_level0_col0" class="col_heading level0 col0" >fit_time</th>
#       <th id="T_c6cee_level0_col1" class="col_heading level0 col1" >score_time</th>
#       <th id="T_c6cee_level0_col2" class="col_heading level0 col2" >test_neg_mean_absolute_error</th>
#       <th id="T_c6cee_level0_col3" class="col_heading level0 col3" >test_neg_root_mean_squared_error</th>
#       <th id="T_c6cee_level0_col4" class="col_heading level0 col4" >test_r2</th>
#       <th id="T_c6cee_level0_col5" class="col_heading level0 col5" >time_seconds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6cee_level0_row0" class="row_heading level0 row0" >LinearRegression_best_estimator</th>
#       <td id="T_c6cee_row0_col0" class="data row0 col0" >1.138016</td>
#       <td id="T_c6cee_row0_col1" class="data row0 col1" >0.021264</td>
#       <td id="T_c6cee_row0_col2" class="data row0 col2" >-36549.853060</td>
#       <td id="T_c6cee_row0_col3" class="data row0 col3" >-52420.467622</td>
#       <td id="T_c6cee_row0_col4" class="data row0 col4" >0.701988</td>
#       <td id="T_c6cee_row0_col5" class="data row0 col5" >1.159280</td>
#     </tr>
#     <tr>
#       <th id="T_c6cee_level0_row1" class="row_heading level0 row1" >LinearRegression_melhor_atual</th>
#       <td id="T_c6cee_row1_col0" class="data row1 col0" >1.103785</td>
#       <td id="T_c6cee_row1_col1" class="data row1 col1" >0.021452</td>
#       <td id="T_c6cee_row1_col2" class="data row1 col2" >-36745.023157</td>
#       <td id="T_c6cee_row1_col3" class="data row1 col3" >-52800.769454</td>
#       <td id="T_c6cee_row1_col4" class="data row1 col4" >0.697560</td>
#       <td id="T_c6cee_row1_col5" class="data row1 col5" >1.141286</td>
#     </tr>
#     <tr>
#       <th id="T_c6cee_level0_row2" class="row_heading level0 row2" >LinearRegression_simples</th>
#       <td id="T_c6cee_row2_col0" class="data row2 col0" >0.029494</td>
#       <td id="T_c6cee_row2_col1" class="data row2 col1" >0.015590</td>
#       <td id="T_c6cee_row2_col2" class="data row2 col2" >-42373.880720</td>
#       <td id="T_c6cee_row2_col3" class="data row2 col3" >-58944.889944</td>
#       <td id="T_c6cee_row2_col4" class="data row2 col4" >0.625750</td>
#       <td id="T_c6cee_row2_col5" class="data row2 col5" >0.046634</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_comparar_metricas_modelos(
    df_resultados=df_resultados,
    comparar_metricas=['test_' + metrica for metrica in dct_metricas_modelos.keys()] + ['time_seconds'],
    nomes_metricas=list(dct_metricas_modelos.values()) + ['tempo (seg)'],
    figsize=(10, 5),
    colunas_graficos=2,
    flg_boxplots_horizontais=True,
)

# %% [markdown]
# ### Sobre o novo modelo encontrado pelo GRID SEARCH
# O novo modelo encontrado pelo GRID SEARCH até consegue vencer o nosso atual melhor modelo. Têm médias e medianas levemente superiores.
#
# Apesar disso, o aumento da complexidade torna o modelo menos interessante diante do pequeno ganho.
#
# Podemos continuar com a versão data etapa 4, que usa features polinomiais, mas não usa regularização.

# %% [markdown]
# ## Resíduos do modelo novo
#
# ### Resíduos sobre a base de teste
# Essa base não participou do treinamento em nenhum momento e são novos para o modelo.

# %%
# dados já separados como X e y de teste
X_test = pd.read_parquet(DADOS_X_TEST)
y_test = pd.read_parquet(DADOS_Y_TEST)

print('X_test.shape', X_test.shape)
print('y_test.shape', y_test.shape)
# Out:
# X_test.shape (3639, 15)
# y_test.shape (3639, 1)

# %%
df_residuos = pd.DataFrame()
df_residuos['residuos'] = y_test - grid_search.predict(X_test)

df_describe = fnc_describe_numericas_personalizado(
    df=df_residuos,
    flg_mostrar_dataframe=False,
    flg_retornar_dataframe=True,
    teste_normalidade='Kolmogorov-Smirnov'
)

df_describe[['dist_normal', 'pvalue', 'teste_normalidade', 'skewness', 'kurtosis',]].T
# Out:
# /dados/app/conda/envs/california/lib/python3.12/site-packages/pandas/core/dtypes/cast.py:377: RuntimeWarning: invalid value encountered in cast
#   new_result = trans(result).astype(dtype)
#                              residuos
# dist_normal                     False
# pvalue                              0
# teste_normalidade  Kolmogorov-Smirnov
# skewness                         0.70
# kurtosis                         3.74

# %%
display(
    df_describe[['min', 'LOWER', '01%', '25%', '50%', '75%', '99%', 'UPPER', 'max', 'mean', 'std',
    ]].style.background_gradient(
        cmap=PALETTE_TEMPERATURA,
        axis='columns',
        subset=['min', 'LOWER', '01%', '25%', '50%', '75%', '99%', 'UPPER', 'max', 'mean',]
    )
)

# boxplot
fig, ax = plt.subplots(figsize=(10, 1))
sns.boxplot(
    data=df_residuos,
    x='residuos',
    showmeans=True,
    ax=ax,
)
# Definindo a orientação dos tick labels do eixo x na vertical
ax.set_xticklabels(
    labels=[int(x) for x in ax.get_xticks()],
    rotation=90,
)
plt.show()
# Out:
# <style type="text/css">
# #T_ea5dc_row0_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ea5dc_row0_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ea5dc_row0_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ea5dc_row0_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ea5dc_row0_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_ea5dc_row0_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_ea5dc_row0_col6 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_ea5dc_row0_col7 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_ea5dc_row0_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ea5dc_row0_col9 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_ea5dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea5dc_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_ea5dc_level0_col1" class="col_heading level0 col1" >LOWER</th>
#       <th id="T_ea5dc_level0_col2" class="col_heading level0 col2" >01%</th>
#       <th id="T_ea5dc_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_ea5dc_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_ea5dc_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_ea5dc_level0_col6" class="col_heading level0 col6" >99%</th>
#       <th id="T_ea5dc_level0_col7" class="col_heading level0 col7" >UPPER</th>
#       <th id="T_ea5dc_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_ea5dc_level0_col9" class="col_heading level0 col9" >mean</th>
#       <th id="T_ea5dc_level0_col10" class="col_heading level0 col10" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea5dc_level0_row0" class="row_heading level0 row0" >residuos</th>
#       <td id="T_ea5dc_row0_col0" class="data row0 col0" >-321894.106961</td>
#       <td id="T_ea5dc_row0_col1" class="data row0 col1" >-103012.085244</td>
#       <td id="T_ea5dc_row0_col2" class="data row0 col2" >-125269.610862</td>
#       <td id="T_ea5dc_row0_col3" class="data row0 col3" >-26157.518844</td>
#       <td id="T_ea5dc_row0_col4" class="data row0 col4" >-3304.716553</td>
#       <td id="T_ea5dc_row0_col5" class="data row0 col5" >25078.858757</td>
#       <td id="T_ea5dc_row0_col6" class="data row0 col6" >172052.366683</td>
#       <td id="T_ea5dc_row0_col7" class="data row0 col7" >101933.425157</td>
#       <td id="T_ea5dc_row0_col8" class="data row0 col8" >326129.370992</td>
#       <td id="T_ea5dc_row0_col9" class="data row0 col9" >2722.314697</td>
#       <td id="T_ea5dc_row0_col10" class="data row0 col10" >52648.196982</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_residuos_estimador(grid_search.best_estimator_, X_test, y_test, fracao_amostra=0.3, eng_formatter=True) #, mosaico='bc;aa')

# %% [markdown]
# ### Resíduos sobre a base de validação
# Essa base não participou do treinamento em nenhum momento e são novos para o modelo.

# %%
y_validation = pd.read_parquet(DADOS_Y_VALIDATION)
X_validation = pd.read_parquet(DADOS_X_VALIDATION)

print('X_validation.shape', X_validation.shape)
print('y_validation.shape', y_validation.shape)
# Out:
# X_validation.shape (1874, 15)
# y_validation.shape (1874, 1)

# %%
df_residuos = pd.DataFrame()
df_residuos['residuos'] = y_validation - grid_search.predict(X_validation)

df_describe = fnc_describe_numericas_personalizado(
    df=df_residuos,
    flg_mostrar_dataframe=False,
    flg_retornar_dataframe=True,
    teste_normalidade='Kolmogorov-Smirnov'
)

df_describe[['dist_normal', 'pvalue', 'teste_normalidade', 'skewness', 'kurtosis',]].T
# Out:
# /dados/app/conda/envs/california/lib/python3.12/site-packages/pandas/core/dtypes/cast.py:377: RuntimeWarning: invalid value encountered in cast
#   new_result = trans(result).astype(dtype)
#                              residuos
# dist_normal                     False
# pvalue                              0
# teste_normalidade  Kolmogorov-Smirnov
# skewness                         0.98
# kurtosis                         4.60

# %%
display(
    df_describe[['min', 'LOWER', '01%', '25%', '50%', '75%', '99%', 'UPPER', 'max', 'mean', 'std',
    ]].style.background_gradient(
        cmap=PALETTE_TEMPERATURA,
        axis='columns',
        subset=['min', 'LOWER', '01%', '25%', '50%', '75%', '99%', 'UPPER', 'max', 'mean',]
    )
)

# boxplot
fig, ax = plt.subplots(figsize=(10, 1))
sns.boxplot(
    data=df_residuos,
    x='residuos',
    showmeans=True,
    ax=ax,
)
# Definindo a orientação dos tick labels do eixo x na vertical
ax.set_xticklabels(
    labels=[int(x) for x in ax.get_xticks()],
    rotation=90,
)
plt.show()
# Out:
# <style type="text/css">
# #T_a6c20_row0_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a6c20_row0_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_a6c20_row0_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_a6c20_row0_col3 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_a6c20_row0_col4 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_a6c20_row0_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_a6c20_row0_col6 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_a6c20_row0_col7 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_a6c20_row0_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a6c20_row0_col9 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# </style>
# <table id="T_a6c20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6c20_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_a6c20_level0_col1" class="col_heading level0 col1" >LOWER</th>
#       <th id="T_a6c20_level0_col2" class="col_heading level0 col2" >01%</th>
#       <th id="T_a6c20_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_a6c20_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_a6c20_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_a6c20_level0_col6" class="col_heading level0 col6" >99%</th>
#       <th id="T_a6c20_level0_col7" class="col_heading level0 col7" >UPPER</th>
#       <th id="T_a6c20_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_a6c20_level0_col9" class="col_heading level0 col9" >mean</th>
#       <th id="T_a6c20_level0_col10" class="col_heading level0 col10" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6c20_level0_row0" class="row_heading level0 row0" >residuos</th>
#       <td id="T_a6c20_row0_col0" class="data row0 col0" >-257378.958592</td>
#       <td id="T_a6c20_row0_col1" class="data row0 col1" >-103448.917927</td>
#       <td id="T_a6c20_row0_col2" class="data row0 col2" >-119746.642792</td>
#       <td id="T_a6c20_row0_col3" class="data row0 col3" >-25730.296258</td>
#       <td id="T_a6c20_row0_col4" class="data row0 col4" >-2104.165039</td>
#       <td id="T_a6c20_row0_col5" class="data row0 col5" >26082.118187</td>
#       <td id="T_a6c20_row0_col6" class="data row0 col6" >191219.107224</td>
#       <td id="T_a6c20_row0_col7" class="data row0 col7" >103800.739855</td>
#       <td id="T_a6c20_row0_col8" class="data row0 col8" >357933.575306</td>
#       <td id="T_a6c20_row0_col9" class="data row0 col9" >3550.613037</td>
#       <td id="T_a6c20_row0_col10" class="data row0 col10" >54726.690538</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_residuos_estimador(grid_search.best_estimator_, X_validation, y_validation, fracao_amostra=0.6, eng_formatter=True) #, mosaico='bc;aa')

# %% [markdown]
# ### Analisando os dados e gráficos de resíduos
# Não podemos notar muita diferença entre nossos novos gráficos e os gráficos da etapa anterior.
#
# Também é importante observar que não temos uma situação de overfitting, pois os dados de validação não participaram do treinamento e ainda assim os resíduos estão próximos que já conhecíamos de etapas anteriores.
#
# Como dito acima, vamos seguir com o modelo da etapa 4, devido a sua simplicidade e desempenho.
